# %% [markdown]
# **Análise Exploratória**

# %%
#importanto as bibliotecas
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
#Upload do arquivo
from google.colab import files
arq = files.upload()
# Out:
#      <input type="file" id="files-c366e792-8357-4d43-be8f-6f8347b31248" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c366e792-8357-4d43-be8f-6f8347b31248">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AdventureWorks.xlsx to AdventureWorks.xlsx

# %%
#criando o DataFrame
df = pd.read_excel("AdventureWorks.xlsx")

# %%
#Visualizando os dados
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...            Marca   Classe  Cor
# 0 2008-05-09 2008-05-29      199  ...  Adventure Works  Regular  Red
# 1 2008-05-12 2008-05-17      306  ...  Adventure Works  Regular  Red
# 2 2008-05-14 2008-05-20      306  ...  Adventure Works  Regular  Red
# 3 2008-05-21 2008-05-27      306  ...  Adventure Works  Regular  Red
# 4 2008-06-20 2008-06-27      306  ...  Adventure Works  Regular  Red
#
# [5 rows x 16 columns]

# %%
#Verificando a quantidade de linhas e colunas
df.shape
# Out:
# (904, 16)

# %%
#Verificando os tipos de dados
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
#Calculando a receita total
df["Valor Venda"].sum()
# Out:
# 5984606.1426

# %%
#Criando a coluna Custo
df["Custo"] = df["Custo Unitário"].mul(df["Quantidade"])

# %%
#Verificando
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...   Classe  Cor    Custo
# 0 2008-05-09 2008-05-29      199  ...  Regular  Red  2091.48
# 1 2008-05-12 2008-05-17      306  ...  Regular  Red  2091.48
# 2 2008-05-14 2008-05-20      306  ...  Regular  Red  2091.48
# 3 2008-05-21 2008-05-27      306  ...  Regular  Red  2091.48
# 4 2008-06-20 2008-06-27      306  ...  Regular  Red  2091.48
#
# [5 rows x 17 columns]

# %%
#Calculando o custo total com 2 casas decimais
round(df["Custo"].sum(),2)
# Out:
# 2486783.05

# %%
#Com a receita e custo total disponível, será calculado o lucro 
#Criando a coluna Lucro = Receita(Valor Venda) - Custo
df["Lucro"] = df["Valor Venda"] - df["Custo"]

# %%
#Verificando
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ...   Classe  Cor    Custo    Lucro
# 0 2008-05-09 2008-05-29      199         384  ...  Regular  Red  2091.48  2456.52
# 1 2008-05-12 2008-05-17      306         384  ...  Regular  Red  2091.48  2456.52
# 2 2008-05-14 2008-05-20      306         384  ...  Regular  Red  2091.48  2456.52
# 3 2008-05-21 2008-05-27      306         384  ...  Regular  Red  2091.48  2456.52
# 4 2008-06-20 2008-06-27      306         384  ...  Regular  Red  2091.48  2456.52
#
# [5 rows x 18 columns]

# %%
#Calculando o Lucro Total
round(df["Lucro"].sum(),2)
# Out:
# 3497823.09

# %%
#Criando uma coluna com o total de dias para enviar o produto
df["Tempo Envio"] = df["Data Envio"] - df["Data Venda"]

# %%
#Verificando
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ...  Cor    Custo    Lucro  Tempo Envio
# 0 2008-05-09 2008-05-29      199         384  ...  Red  2091.48  2456.52      20 days
# 1 2008-05-12 2008-05-17      306         384  ...  Red  2091.48  2456.52       5 days
# 2 2008-05-14 2008-05-20      306         384  ...  Red  2091.48  2456.52       6 days
# 3 2008-05-21 2008-05-27      306         384  ...  Red  2091.48  2456.52       6 days
# 4 2008-06-20 2008-06-27      306         384  ...  Red  2091.48  2456.52       7 days
#
# [5 rows x 19 columns]

# %% [markdown]
# **Verificando tempo médio de envio, para isso será necessário transformar a coluna Tempo Envio para numérica**

# %%
#Extraindo apenas os dias
df["Tempo Envio"] = (df["Data Envio"] - df["Data Venda"]).dt.days

# %%
#Verificando
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...    Custo    Lucro Tempo Envio
# 0 2008-05-09 2008-05-29      199  ...  2091.48  2456.52          20
# 1 2008-05-12 2008-05-17      306  ...  2091.48  2456.52           5
# 2 2008-05-14 2008-05-20      306  ...  2091.48  2456.52           6
# 3 2008-05-21 2008-05-27      306  ...  2091.48  2456.52           6
# 4 2008-06-20 2008-06-27      306  ...  2091.48  2456.52           7
#
# [5 rows x 19 columns]

# %%
#Verificando o tipo da coluna Tempo Envio
df["Tempo Envio"].dtypes
# Out:
# dtype('int64')

# %%
#Verificando a média de tempo de envio por Marca
df.groupby("Marca")["Tempo Envio"].mean()
# Out:
# Marca
# Adventure Works    8.663866
# Contoso            8.470930
# Fabrikam           8.510121
# Name: Tempo Envio, dtype: float64

# %%
#Verificando se tem dados faltando
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# Custo             0
# Lucro             0
# Tempo Envio       0
# dtype: int64

# %% [markdown]
# **Verificando o Lucro por Ano e Marca**

# %%
#Agrupando por Ano e Marca
df.groupby([df["Data Venda"].dt.year, "Marca"])["Lucro"].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works    3.066412e+05
#             Contoso            5.641600e+04
#             Fabrikam           1.557021e+06
# 2009        Adventure Works    4.053951e+05
#             Contoso            1.382590e+05
#             Fabrikam           1.034091e+06
# Name: Lucro, dtype: float64

# %%
#Alterando o formato
pd.options.display.float_format = "{:20,.2f}".format

# %%
#Resetando o index
lucro_ano = df.groupby([df["Data Venda"].dt.year, "Marca"])["Lucro"].sum().reset_index()
lucro_ano
# Out:
#    Data Venda            Marca                Lucro
# 0        2008  Adventure Works           306,641.16
# 1        2008          Contoso            56,416.00
# 2        2008         Fabrikam         1,557,020.55
# 3        2009  Adventure Works           405,395.08
# 4        2009          Contoso           138,258.95
# 5        2009         Fabrikam         1,034,091.35

# %%
#Calculando o total de produtos vendidos
df.groupby("Produto")["Quantidade"].sum().sort_values(ascending=False)
# Out:
# Produto
# Headphone Adapter for Contoso Phone E130 Silver    25232
# Headphone Adapter for Contoso Phone E130 White     25008
# Adventure Works Laptop15.4W M1548 Black             1089
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey           1087
# Adventure Works Laptop15.4W M1548 Red               1047
# Fabrikam Trendsetter 2/3'' 17mm X100 Black           926
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black          884
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey           845
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White          789
# Name: Quantidade, dtype: int64

# %%
#Gráfico do Total de Produtos Vendidos
df.groupby("Produto")["Quantidade"].sum().sort_values(ascending=False).plot.barh(title="Total Produtos Vendidos", color="skyblue")
plt.xlabel("Total")
plt.ylabel("Produto");

# %%
#Criando gráfico de Lucro x Ano
df.groupby(df["Data Venda"].dt.year)["Lucro"].sum().plot.bar(title="Lucro x Ano", color="skyblue")
plt.xlabel("Ano")
plt.ylabel("Lucro");

# %%
#Verificando os valores
df.groupby(df["Data Venda"].dt.year)["Lucro"].sum()
# Out:
# Data Venda
# 2008           1,920,077.71
# 2009           1,577,745.38
# Name: Lucro, dtype: float64

# %%
#Selecionando apenas as vendas de 2009
df_2009 = df[df["Data Venda"].dt.year == 2009]

# %%
#verificando
df_2009.head()
# Out:
#    Data Venda Data Envio  ...                Lucro  Tempo Envio
# 11 2009-05-02 2009-05-14  ...             2,456.52           12
# 12 2009-05-16 2009-05-27  ...             2,456.52           11
# 13 2009-05-31 2009-06-12  ...             2,456.52           12
# 14 2009-06-28 2009-07-11  ...             2,456.52           13
# 15 2009-07-08 2009-07-12  ...             2,456.52            4
#
# [5 rows x 19 columns]

# %%
#Gráfico de linha Lucro x Mês
df_2009.groupby(df_2009["Data Venda"].dt.month)["Lucro"].sum().plot(title="Lucro x Mês")
plt.xlabel("Mês")
plt.ylabel("Lucro");

# %%
#Gráfico de Lucro x Marca
df_2009.groupby("Marca")["Lucro"].sum().plot.bar(title="Lucro x Marca")
plt.xlabel("Marca")
plt.ylabel("Lucro")
plt.xticks(rotation="horizontal");

# %%
#Gráfico de Lucro x Classe
df_2009.groupby("Classe")["Lucro"].sum().plot.bar(title="Lucro x Classe")
plt.xlabel("Classe")
plt.ylabel("Lucro")
plt.xticks(rotation="horizontal");

# %%
#Dados estatíticos relativo ao tempo de envio
df["Tempo Envio"].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: Tempo Envio, dtype: float64

# %%
#Criando um gráfico de Boxplot
plt.boxplot(df["Tempo Envio"]);

# %%
#Criando um histograma
plt.hist(df["Tempo Envio"], color="skyblue");

# %%
#Verificando o Tempo mínino de envio
df["Tempo Envio"].min()
# Out:
# 4

# %%
#Verificando o Tempo máximo de envio
df["Tempo Envio"].max()
# Out:
# 20

# %%
#Identificando o Outlier
df[df["Tempo Envio"] == 20]
# Out:
#   Data Venda Data Envio  ...                Lucro  Tempo Envio
# 0 2008-05-09 2008-05-29  ...             2,456.52           20
#
# [1 rows x 19 columns]

# %%
#Salvando os dados em um novo arquivo csv
df.to_csv("df_vendas_novo.csv", index=False)
